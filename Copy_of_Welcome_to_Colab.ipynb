# %% [markdown]
# <a href="https://colab.research.google.com/github/JMMvelase/OpenCv/blob/main/Copy_of_Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-16591f33-f046-4ec4-9841-9e486a6dae41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16591f33-f046-4ec4-9841-9e486a6dae41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -q ppe_data.zip -d ppe_data

# %%
# !ls -R ppe_data
# Out:
# ppe_data:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
#
# ppe_data/test:
# images	labels
#
# ppe_data/test/images:
# boots-32-_jpeg.rf.fa7a8751c2bdf105d350504bce0b94cb.jpg
# boots-33-_jpeg.rf.68d38a4e04970e7596ac405ba36ea5da.jpg
# boots-39-_jpeg.rf.13f796632e240af680bcc2ade6154071.jpg
# boots-50-_jpeg.rf.1590e15b752c32b4048ffc92e548980e.jpg
# boots-71-_jpeg.rf.42ad6262088cb712c54f3f5bfa03dd1f.jpg
# boots-75-_jpeg.rf.1a480cdecffadeefef304ec58ac59796.jpg
# ear-16-_jpeg.rf.426a4bc89798347161ff3ec720a3d063.jpg
# ear-25-_jpeg.rf.9023d79a67ab1882ced3a7dbc1ce4560.jpg
# ear-45-_jpeg.rf.d2e9c017ba0a2f37f031d7714b944541.jpg
# ear-51-_jpeg.rf.e523c1315d48dc8425c9f333747b7ce2.jpg
# ear-57-_jpeg.rf.2d1dee57c4bae8720f813920eb5ecc3a.jpg
# ear-60-_jpeg.rf.997d1cc3fda0922dce7dbfd032810245.jpg
# glass-29-_jpeg.rf.fb99034437fa2f521d908000863116a4.jpg
# glass-31-_jpeg.rf.eb2bf9f34dab463da3e91ca9176933d2.jpg
# glasses-1-_jpeg.rf.cb7274902ab80c1e58c47d4d5af9b0ac.jpg
# ...

# %%
# !pip install ultralytics

# %%
# !ls ppe_data
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
model.train(data='ppe_data/data.yaml', epochs=50)
# Out:
# Ultralytics 8.3.147 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files
files.download('runs/detect/train3/weights/best.pt')
